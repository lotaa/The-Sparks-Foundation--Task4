# %% [markdown]
# ## Auther: Omnia Hosny
#    ## Internship :The Sparks Foundation

# %% [markdown]
# # **EXPLORATORTY DATA ANLYSIS: TERRORISM**
# - Perform EAD on dataset 'Global_Terrorism'
# - As a security defense analyst, Try to find out the hot zone of terrorism.
# # **THE GOAL**:  What all Security issues and insights you can derive by EDA.
# * High level understanding of data (look at columns, nulls, shape, etc)
#
# * Understand relationship between columns (Multiple answer vs single answer)

# %% [markdown]
# # The questions will be answer.
# * 1- What is the top contries affected?
# * 2- What is total attackes?
# * 3- What is the total attackes in each year?
# * 4- How many attacks lasted more than 24?
# * 5- How many attack is suicide?
# * 6- How many attack is successful?
# * 7- What What is the total attackes in each city?
# * 8- What is most method of attack and broad class of tactics used?
# * 9- How many victims of the attack?
# * 10- What is the country with the most casualties?

# %%
# Importing all libraries required in this notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
# Reading data from remote link
url = "globalterrorismdb_0718dist.csv"
data = pd.read_csv(url)
data.head()
# Out:
# C:\Users\Omnia Hosny\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
# Shape of data
data.shape
# Out:
# (181691, 135)

# %%
#information About the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# 25%         0.000000      78.000000       5.000000      11.510046
# 50%         0.000000      98.000000       6.000000      31.467463
# 75%         0.000000     160.000000      10.000000      34.685087
# max         1.000000    1004.000000      12.000000      74.633553
#
#           longitude    specificity  ...     ransomamt   ransomamtus  \
# count  1.771340e+05  181685.000000  ...  1.350000e+03  5.630000e+02
# mean  -4.586957e+02       1.451452  ...  3.172530e+06  5.784865e+05
# std    2.047790e+05       0.995430  ...  3.021157e+07  7.077924e+06
# min   -8.618590e+07       1.000000  ... -9.900000e+01 -9.900000e+01
# 25%    4.545640e+00       1.000000  ...  0.000000e+00  0.000000e+00
# 50%    4.324651e+01       1.000000  ...  1.500000e+04  0.000000e+00
# 75%    6.871033e+01       1.000000  ...  4.000000e+05  0.000000e+00
# max    1.793667e+02       5.000000  ...  1.000000e+09  1.320000e+08
#
#          ransompaid  ransompaidus  hostkidoutcome     nreleased  \
# count  7.740000e+02    552.000000    10991.000000  10400.000000
# mean   7.179437e+05    240.378623        4.629242    -29.018269
# std    1.014392e+07   2940.967293        2.035360     65.720119
# min   -9.900000e+01    -99.000000        1.000000    -99.000000
# 25%   -9.900000e+01      0.000000        2.000000    -99.000000
# 50%    0.000000e+00      0.000000        4.000000      0.000000
# 75%    1.273412e+03      0.000000        7.000000      1.000000
# max    2.750000e+08  48000.000000        7.000000   2769.000000
#
#              INT_LOG       INT_IDEO       INT_MISC        INT_ANY
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean       -4.543731      -4.464398       0.090010      -3.945952
# std         4.543547       4.637152       0.568457       4.691325
# min        -9.000000      -9.000000      -9.000000      -9.000000
# 25%        -9.000000      -9.000000       0.000000      -9.000000
# 50%        -9.000000      -9.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 77 columns]

# %%
#know names of columns 
for col in data.columns:
    print(col)
# Out:
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# weaptype1_txt
# weapsubtype1
# weapsubtype1_txt
# weaptype2
# weaptype2_txt
# weapsubtype2
# weapsubtype2_txt
# weaptype3
# weaptype3_txt
# weapsubtype3
# weapsubtype3_txt
# weaptype4
# weaptype4_txt
# weapsubtype4
# weapsubtype4_txt
# weapdetail
# nkill
# nkillus
# nkillter
# nwound
# nwoundus
# nwoundte
# property
# propextent
# propextent_txt
# propvalue
# propcomment
# ishostkid
# nhostkid
# nhostkidus
# nhours
# ndays
# divert
# kidhijcountry
# ransom
# ransomamt
# ransomamtus
# ransompaid
# ransompaidus
# ransomnote
# hostkidoutcome
# hostkidoutcome_txt
# nreleased
# addnotes
# scite1
# scite2
# scite3
# dbsource
# INT_LOG
# INT_IDEO
# INT_MISC
# INT_ANY
# related

# %%
# Check the nulls Values
data.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
#no. of duplicated rows
data.duplicated().sum()
# Out:
# 0

# %%
data.nunique()
# Out:
# eventid       181691
# iyear             47
# imonth            13
# iday              32
# approxdate      2244
#                ...
# INT_LOG            3
# INT_IDEO           3
# INT_MISC           3
# INT_ANY            3
# related        14306
# Length: 135, dtype: int64

# %% [markdown]
# ## OBSERVATIONS of Quality

# %% [markdown]
# I Selected columns that vaild, and I will used in analysis.
# [eventid, iyear, imonth, iday, extended, country_txt, region_txt, city, success, suicide, attacktype1_txt, attacktype1, targtype1_txt, targsubtype1_txt, gname, weaptype_txt, weapsubtype1_txt, nkill]
# country rename to country code, country_txt rename to country, region_txt rename to region,

# %% [markdown]
# ## Cleaning
# ### Drop columns that is unusefull for this notebook and not valid.

# %%
df = data.filter(['eventid', 'iyear', 'imonth', 'iday', 'extended', 'country_txt', 'region_txt', 'city', 'success', 'suicide', 'attacktype1_txt', 'attacktype1', 'targtype1_txt', 'targsubtype1_txt,' 'gname', 'weaptype1_txt', 'nkill'], axis=1)
df.head()
df.tail()
# Out:
#              eventid  iyear  imonth  iday  extended  country_txt  \
# 181686  201712310022   2017      12    31         0      Somalia
# 181687  201712310029   2017      12    31         0        Syria
# 181688  201712310030   2017      12    31         0  Philippines
# 181689  201712310031   2017      12    31         0        India
# 181690  201712310032   2017      12    31         0  Philippines
#
#                         region_txt           city  success  suicide  \
# 181686          Sub-Saharan Africa  Ceelka Geelow        1        0
# 181687  Middle East & North Africa         Jableh        1        0
# 181688              Southeast Asia       Kubentog        1        0
# 181689                  South Asia         Imphal        0        0
# 181690              Southeast Asia  Cotabato City        0        0
#
#                        attacktype1_txt  attacktype1  \
# 181686                   Armed Assault            2
# 181687               Bombing/Explosion            3
# 181688  Facility/Infrastructure Attack            7
# 181689               Bombing/Explosion            3
# 181690               Bombing/Explosion            3
#
#                       targtype1_txt weaptype1_txt  nkill
# 181686                     Military      Firearms    1.0
# 181687                     Military    Explosives    2.0
# 181688  Private Citizens & Property    Incendiary    0.0
# 181689         Government (General)    Explosives    0.0
# 181690                      Unknown    Explosives    0.0

# %%
#check nulls
df.isnull().sum()
# Out:
# eventid                0
# iyear                  0
# imonth                 0
# iday                   0
# extended               0
# country_txt            0
# region_txt             0
# city                 434
# success                0
# suicide                0
# attacktype1_txt        0
# attacktype1            0
# targtype1_txt          0
# weaptype1_txt          0
# nkill              10313
# dtype: int64

# %% [markdown]
# #### Drop nulls from 'nkill'

# %%
df.dropna(subset=['nkill','city'])
# Out:
#              eventid  iyear  imonth  iday  extended         country_txt  \
# 0       197000000001   1970       7     2         0  Dominican Republic
# 1       197000000002   1970       0     0         0              Mexico
# 2       197001000001   1970       1     0         0         Philippines
# 5       197001010002   1970       1     1         0       United States
# 6       197001020001   1970       1     2         0             Uruguay
# ...              ...    ...     ...   ...       ...                 ...
# 181686  201712310022   2017      12    31         0             Somalia
# 181687  201712310029   2017      12    31         0               Syria
# 181688  201712310030   2017      12    31         0         Philippines
# 181689  201712310031   2017      12    31         0               India
# 181690  201712310032   2017      12    31         0         Philippines
#
#                          region_txt           city  success  suicide  \
# 0       Central America & Caribbean  Santo Domingo        1        0
# 1                     North America    Mexico city        1        0
# 2                    Southeast Asia        Unknown        1        0
# 5                     North America          Cairo        1        0
# 6                     South America     Montevideo        0        0
# ...                             ...            ...      ...      ...
# 181686           Sub-Saharan Africa  Ceelka Geelow        1        0
# 181687   Middle East & North Africa         Jableh        1        0
# 181688               Southeast Asia       Kubentog        1        0
# 181689                   South Asia         Imphal        0        0
# 181690               Southeast Asia  Cotabato City        0        0
#
#                        attacktype1_txt  attacktype1  \
# 0                        Assassination            1
# 1          Hostage Taking (Kidnapping)            6
# 2                        Assassination            1
# 5                        Armed Assault            2
# 6                        Assassination            1
# ...                                ...          ...
# 181686                   Armed Assault            2
# 181687               Bombing/Explosion            3
# 181688  Facility/Infrastructure Attack            7
# 181689               Bombing/Explosion            3
# 181690               Bombing/Explosion            3
#
#                       targtype1_txt weaptype1_txt  nkill
# 0       Private Citizens & Property       Unknown    1.0
# 1           Government (Diplomatic)       Unknown    0.0
# 2               Journalists & Media       Unknown    1.0
# 5                            Police      Firearms    0.0
# 6                            Police      Firearms    0.0
# ...                             ...           ...    ...
# 181686                     Military      Firearms    1.0
# 181687                     Military    Explosives    2.0
# 181688  Private Citizens & Property    Incendiary    0.0
# 181689         Government (General)    Explosives    0.0
# 181690                      Unknown    Explosives    0.0
#
# [170944 rows x 15 columns]

# %%
sum(df.nkill.isnull())
# Out:
# 10313

# %% [markdown]
# ##### rename colums

# %%
df.rename(columns = {'iyear':'year', 'imonth':'month', 'iday':'day', 'extended': 'during_24', 'country_txt':'country', 'region_txt':'region', 'attacktype1_txt':'attack_type', 'targtype1_txt':'targt_type', 'targsubtype1_txt': 'targt_sub_type', 'gname':'group_name', 'weaptype1_txt':'weap_type'}, inplace=True)
df.head()
# Out:
#         eventid  year  month  day  during_24             country  \
# 0  197000000001  1970      7    2          0  Dominican Republic
# 1  197000000002  1970      0    0          0              Mexico
# 2  197001000001  1970      1    0          0         Philippines
# 3  197001000002  1970      1    0          0              Greece
# 4  197001000003  1970      1    0          0               Japan
#
#                         region           city  success  suicide  \
# 0  Central America & Caribbean  Santo Domingo        1        0
# 1                North America    Mexico city        1        0
# 2               Southeast Asia        Unknown        1        0
# 3               Western Europe         Athens        1        0
# 4                    East Asia        Fukouka        1        0
#
#                       attack_type  attacktype1                   targt_type  \
# 0                   Assassination            1  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)            6      Government (Diplomatic)
# 2                   Assassination            1          Journalists & Media
# 3               Bombing/Explosion            3      Government (Diplomatic)
# 4  Facility/Infrastructure Attack            7      Government (Diplomatic)
#
#     weap_type  nkill
# 0     Unknown    1.0
# 1     Unknown    0.0
# 2     Unknown    1.0
# 3  Explosives    NaN
# 4  Incendiary    NaN

# %% [markdown]
# ## Q1- What is the total countries affected?

# %%
df[['country']].nunique()
# Out:
# country    205
# dtype: int64

# %% [markdown]
# #####  There are 205 country affected by attacks

# %% [markdown]
# ## 2- What is the top countries affected?

# %%
group=pd.DataFrame(df.groupby(['country'])['success'].count().sort_values(ascending=False)[:20])
sns.barplot(y=group.index, x=group.values.ravel(), data=group)
# Out:
# <AxesSubplot:ylabel='country'>

# %%
df.describe()
# Out:
#             eventid           year          month            day  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#            during_24        success        suicide    attacktype1  \
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean        0.045346       0.889598       0.036507       3.247547
# std         0.208063       0.313391       0.187549       1.915772
# min         0.000000       0.000000       0.000000       1.000000
# 25%         0.000000       1.000000       0.000000       2.000000
# 50%         0.000000       1.000000       0.000000       3.000000
# 75%         0.000000       1.000000       0.000000       3.000000
# max         1.000000       1.000000       1.000000       9.000000
#
#                nkill
# count  171378.000000
# mean        2.403272
# std        11.545741
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.000000
# max      1570.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 15 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   eventid      181691 non-null  int64
#  1   year         181691 non-null  int64
#  2   month        181691 non-null  int64
#  3   day          181691 non-null  int64
#  4   during_24    181691 non-null  int64
#  5   country      181691 non-null  object
#  6   region       181691 non-null  object
#  7   city         181257 non-null  object
#  8   success      181691 non-null  int64
#  9   suicide      181691 non-null  int64
#  10  attack_type  181691 non-null  object
#  11  attacktype1  181691 non-null  int64
#  12  targt_type   181691 non-null  object
#  13  weap_type    181691 non-null  object
#  14  nkill        171378 non-null  float64
# dtypes: float64(1), int64(8), object(6)
# memory usage: 20.8+ MB

# %% [markdown]
# I change type of year, month, day to datetime
# convert success to boolen

# %%
(df['city'] == 'Unknown').sum()

# %%
df['city'].value_counts()

# %% [markdown]
# ### 3- What is the total attackes in each Decade?

# %%
group= pd.DataFrame(df.groupby(['year'])['success'].count())
sns.lineplot(data=group)
x = [1970, 1980, 1990, 2000, 2010, 2020]
plt.xticks(x)
plt.title(" Total Attackes In Each Decade")
plt.xlabel(" Year")
plt.ylabel(" Count Of Attacks")
# Out:
# Text(0, 0.5, ' Count Of Attacks')

# %% [markdown]
# *  AS We See least decade is most attackes

# %%
pd.DataFrame(df.groupby(['year'])['success'].count().sort_values(ascending=False))
# Out:
#       success
# year
# 2014    16903
# 2015    14965
# 2016    13587
# 2013    12036
# 2017    10900
# 2012     8522
# 2011     5076
# 1992     5071
# 2010     4826
# 2008     4805
# 2009     4721
# 1991     4683
# 1989     4324
# 1990     3887
# 1988     3721
# 1984     3495
# 1994     3456
# 2007     3242
# 1997     3197
# 1987     3183
# 1995     3081
# 1996     3058
# 1985     2915
# 1983     2870
# 1986     2860
# 2006     2758
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 2005     2017
# 2001     1906
# 2000     1814
# 1978     1526
# 1999     1395
# 2002     1333
# 1977     1319
# 2003     1278
# 2004     1166
# 1998      934
# 1976      923
# 1975      740
# 1970      651
# 1974      581
# 1972      568
# 1973      473
# 1971      471

# %% [markdown]
# ### 5- How many attacks lasted more than 24?

# %%
group = pd.DataFrame(df.groupby(df['during_24'])['success'].count())
sns.barplot(x=group.index, y=group.values.ravel(), data=group)
x=['Less Than 24 Hour', 'More Than 24 Hour']
plt.xticks(range(0,len(group.index)),x)
plt.title("Attack duration")
plt.xlabel("Duration")
plt.ylabel("Count OF Attackes")
# Out:
# Text(0, 0.5, 'Count OF Attackes')

# %% [markdown]
# ### 6- How many attacks are suicide?

# %%
group = pd.DataFrame(df.groupby(df['suicide'])['success'].count())
sns.barplot(x=group.index, y=group.values.ravel(), data=group)
x=['No Suicide', 'Suicide']
plt.xticks(range(0,len(group.index)),x)
plt.title("Count Of Suicide Attacks")
plt.xlabel("Suicide")
plt.ylabel("Count OF Attackes")
# Out:
# Text(0, 0.5, 'Count OF Attackes')

# %% [markdown]
# ### 8-  What are the total attacks in each city?

# %%
group = pd.DataFrame(df.groupby(df['city'])['success'].count().sort_values(ascending=False)[:10])
sns.barplot(y=group.index, x=group.values.ravel(), data=group)
plt.title("Top City Of Attacks")
# Out:
# Text(0.5, 1.0, 'Top City Of Attacks')

# %% [markdown]
# ### 9- What is a most method of attack and broad class of tactics used?

# %%
fig,ax = plt.subplots(1)
ax = df['attack_type'].value_counts().plot(kind='bar')
ax.set_xlabel('Type of Attack')   # replace with the labels you want
ax.set_ylabel('COUNT')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# As we show There are more than 8 types of attack. the most popular is Bombing/Explosion

# %% [markdown]
# ### 9- How many victims of the attack?

# %%
df["nkill"].sum()
# Out:
# 411868.0

# %% [markdown]
# ### 10- What is the country with the most casualties?

# %%
group = pd.DataFrame(df.groupby(df['country'])['nkill'].count().sort_values(ascending=False)[:20])
sns.barplot(y=group.index, x=group.values.ravel(), data=group)
plt.title("Top Country Has Large No. Of casualties ")
plt.xlabel("Count of casualties")
# Out:
# Text(0.5, 0, 'Count of casualties')
